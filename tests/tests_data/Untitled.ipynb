# %%
import pickle
with open("test_hw_02_table.ini.pkl", "rb") as f:
    data1 = pickle.load(f)

# %%
data1
# Out:
# [(b'\xd0\x9d\xd0\xb0\xd0\xb7\xd0\xb2\xd0\xb0\xd0\xbd\xd0\xb8\xd0\xb5\t\xd0\xa1\xd1\x81\xd1\x8b\xd0\xbb\xd0\xba\xd0\xb0\t\xd0\xa2\xd0\xb5\xd0\xb3\xd0\xb8\t\xd0\x9e\xd1\x86\xd0\xb5\xd0\xbd\xd0\xba\xd0\xb0\n\xd0\x9c\xd0\xb8\xd1\x84\xd1\x8b \xd1\x81\xd0\xbe\xd0\xb2\xd1\x80\xd0\xb5\xd0\xbc\xd0\xb5\xd0\xbd\xd0\xbd\xd0\xbe\xd0\xb9 \xd0\xbf\xd0\xbe\xd0\xbf\xd1\x83\xd0\xbb\xd1\x8f\xd1\x80\xd0\xbd\xd0\xbe\xd0\xb9 \xd1\x84\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xba\xd0\xb8\thttps://habr.com/ru/post/442444/\t\xd1\x84\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xba\xd0\xb0\t5\n\xd0\x96\xd0\xb8\xd0\xb7\xd0\xbd\xd1\x8c \xd0\xbd\xd0\xb0 \xd1\x87\xd0\xb0\xd1\x81\xd1\x82\xd0\xb8\xd1\x86\xd0\xb0\xd1\x85\thttps://habr.com/ru/post/442128/\t\xd1\x84\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xba\xd0\xb0\t4\n\xd0\xa7\xd0\xb5\xd0\xbc \xd1\x81\xd0\xb2\xd0\xb5\xd1\x82\xd0\xb8\xd1\x82 Crew Dragon \xd0\xa0\xd0\xbe\xd1\x81\xd0\xba\xd0\xbe\xd1\x81\xd0\xbc\xd0\xbe\xd1\x81\xd1\x83\thttps://habr.com/ru/post/442484/\t\xd0\xba\xd0\xbe\xd1\x81\xd0\xbc\xd0\xbe\
# ...

# %%
for k in data1:
    try:
        print (k[0].decode( 'utf8' ),k[1])
    except :
        print ('not utf-8')
        try:
            print (k[0].decode( 'cp1251' ),k[1])
        except:
            prinr ('unlucky')
# Out:
# Название	Ссылка	Теги	Оценка
# Мифы современной популярной физики	https://habr.com/ru/post/442444/	физика	5
# Жизнь на частицах	https://habr.com/ru/post/442128/	физика	4
# Чем светит Crew Dragon Роскосмосу	https://habr.com/ru/post/442484/	космос	5
# Отправка сообщений об опечатках в публикациях	https://habr.com/ru/company/tm/blog/442208/	опечатки	4
# Google Safe Browsing — пришла беда откуда не ждали	https://habr.com/ru/post/440240/	иб	3
# Реинтродукция зубров (маленькая победа зоологов)	https://habr.com/ru/post/442032/	экология	3
# Плотность сюжета в рознице	https://habr.com/ru/company/mosigra/blog/442376/	розница	1
#
# -------------------------------------------------------------------------------------------------------------------------------------
# |                       Название                       |                       Ссылка                       |    Теги    |  Оценка  |
# ...

# %%
listik = [{}]

# %%
len(listik[0])
# Out:
# 0

# %%
 with open('tes',encoding =  'cp1251') as f:
        data = csv.reader(f, delimiter="\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-390730828510> in <module>()
# ----> 1 with open('movie_metadata.csv',encoding =  'cp1251') as f:
#       2        data = csv.reader(f, delimiter="\t")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'movie_metadata.csv'
